# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# ## データの情報を見る

# %%
train_df = pd.read_csv("../data/train.csv")
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3672 entries, 0 to 3671
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             3672 non-null   int64
#  1   match_date     3672 non-null   object
#  2   kick_off_time  3672 non-null   object
#  3   section        3672 non-null   object
#  4   round          3672 non-null   object
#  5   home_team      3672 non-null   object
#  6   away_team      3672 non-null   object
#  7   venue          3672 non-null   object
#  8   weather        3672 non-null   object
#  9   temperature    3672 non-null   float64
#  10  humidity       3672 non-null   int64
#  11  broadcasters   3672 non-null   object
#  12  attendance     3672 non-null   int64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 373.1+ KB

# %%
display(train_df)
# Out:
#          id  match_date kick_off_time section round home_team away_team  \
# 0      9190  2006-03-04         16:04     第1節   第1日       G大阪        浦和
# 1      9191  2006-03-05         13:00     第1節   第2日        甲府        清水
# 2      9192  2006-03-05         13:35     第1節   第2日      FC東京        大分
# 3      9193  2006-03-05         14:04     第1節   第2日        磐田        福岡
# 4      9194  2006-03-05         14:04     第1節   第2日       名古屋       C大阪
# ...     ...         ...           ...     ...   ...       ...       ...
# 3667  19376  2017-12-02         14:03    第34節   第1日       川崎Ｆ        大宮
# 3668  19377  2017-12-02         14:03    第34節   第1日        甲府        仙台
# 3669  19378  2017-12-02         14:04    第34節   第1日        新潟       Ｃ大阪
# 3670  19379  2017-12-02         14:03    第34節   第1日        磐田        鹿島
# 3671  19380  2017-12-02         14:03    第34節   第1日        神戸        清水
#
#                   venue weather  temperature  ...  away_team_player4  \
# 0               万博記念競技場       晴          8.3  ...         20 堀之内聖 DF
# 1      山梨県小瀬スポーツ公園陸上競技場       晴         12.9  ...          4 高木和道 DF
# 2              味の素スタジアム       晴         12.1  ...         22 上本大海 DF
# 3            静岡スタジアムエコパ       晴         11.6  ...         5 千代反田充 DF
# 4           名古屋市瑞穂陸上競技場       晴         13.1  ...          3 柳本啓成 DF
# ...                 ...     ...          ...  ...                ...
# 3667           等々力陸上競技場       晴         11.7  ...         25 高山和真 DF
# 3668          山梨中銀スタジアム       晴         18.3  ...         27 大岩一貴 DF
# 3669     デンカビッグスワンスタジアム       晴          6.7  ...         15 木本恭生 DF
# 3670       ヤマハスタジアム(磐田)       晴         17.7  ...           3 昌子源 DF
# 3671  神戸総合運動公園ユニバー記念競技場       晴         13.3  ...          45 角田誠 DF
#
#      away_team_player5  away_team_player6   away_team_player7  \
# 0            6 山田暢久 MF         17 長谷部誠 MF          13 鈴木啓太 MF
# 1            3 山西尊裕 DF         13 兵働昭弘 MF           7 伊東輝悦 MF
# 2          5 エジミウソン MF        11 トゥーリオ MF           6 梅田高志 MF
# 3           3 アレックス DF          7 宮崎光平 MF           6 布部陽功 MF
# 4            4 河村崇大 MF         23 下村東美 MF           10 ピンゴ MF
# ...                ...                ...                 ...
# 3667        22 和田拓也 DF           7 江坂任 MF  28 長谷川アーリアジャスール MF
# 3668        50 増嶋竜也 DF          7 奥埜博亮 MF          18 三田啓貴 MF
# 3669     22 マテイヨニッチ DF           6 ソウザ MF          16 水沼宏太 MF
# 3670        16 山本脩斗 DF         20 三竿健斗 MF          4 レオシルバ MF
# 3671         25 松原后 DF         24 増田誓志 MF           20 竹内涼 MF
#
#      away_team_player8 away_team_player9 away_team_player10  \
# 0       8 三都主アレサンドロ MF        18 小野伸二 MF          10 ポンテ FW
# 1           16 枝村匠馬 MF        10 藤本淳吾 MF       18 チョジェジン FW
# 2           17 根本裕一 MF        26 内村圭宏 MF         13 高松大樹 FW
# 3            8 ホベルト MF        14 古賀誠史 MF         27 田中佑昌 FW
# 4           6 ゼカルロス MF         8 森島寛晃 FW         20 西澤明訓 FW
# ...                ...               ...                ...
# 3667        40 茨田陽生 MF        44 瀬川祐輔 MF         16 マテウス FW
# 3668        29 古林将太 MF       16 野津田岳人 MF         30 西村拓真 FW
# 3669        24 山村和也 MF        46 清武弘嗣 MF         8 柿谷曜一朗 FW
# 3670         25 遠藤康 MF       11 レアンドロ MF         33 金崎夢生 FW
# 3671        30 金子翔太 MF   19 ミッチェルデューク MF         23 北川航也 FW
#
#      away_team_player11 holiday_date description
# 0           21 ワシントン FW          NaN         NaN
# 1         17 マルキーニョス FW          NaN         NaN
# 2            9 オズマール FW          NaN         NaN
# 3           36 グラウシオ FW          NaN         NaN
# 4             9 古橋達弥 FW          NaN         NaN
# ...                 ...          ...         ...
# 3667    33 マルセロトスカーノ FW          NaN         NaN
# 3668         11 石原直樹 FW          NaN         NaN
# 3669          9 杉本健勇 FW          NaN         NaN
# 3670          8 土居聖真 FW          NaN         NaN
# 3671           9 鄭大世 FW          NaN         NaN
#
# [3672 rows x 41 columns]

# %%
venue_info_df = pd.read_csv("../data/venue_information.csv")
# venue_info_df.head(5)
venue_info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   venue     120 non-null    object
#  1   capacity  120 non-null    int64
#  2   address   120 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 2.9+ KB

# %%
match_reports_df = pd.read_csv("../data/match_reports.csv")
# match_reports_df.head()
match_reports_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4284 entries, 0 to 4283
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  4284 non-null   int64
#  1   home_team_player11  4284 non-null   object
#  2   home_team_player10  4284 non-null   object
#  3   home_team_player9   4284 non-null   object
#  4   home_team_player8   4284 non-null   object
#  5   home_team_player7   4284 non-null   object
#  6   home_team_player6   4284 non-null   object
#  7   home_team_player5   4284 non-null   object
#  8   home_team_player4   4284 non-null   object
#  9   home_team_player3   4284 non-null   object
#  10  home_team_player2   4284 non-null   object
#  11  home_team_player1   4284 non-null   object
#  12  home_team_score     4284 non-null   int64
#  13  away_team_score     4284 non-null   int64
#  14  away_team_player1   4284 non-null   object
#  15  away_team_player2   4284 non-null   object
#  16  away_team_player3   4284 non-null   object
#  17  away_team_player4   4284 non-null   object
#  18  away_team_player5   4284 non-null   object
#  19  away_team_player6   4284 non-null   object
#  20  away_team_player7   4284 non-null   object
#  21  away_team_player8   4284 non-null   object
#  22  away_team_player9   4284 non-null   object
#  23  away_team_player10  4284 non-null   object
#  24  away_team_player11  4284 non-null   object
# dtypes: int64(3), object(22)
# memory usage: 836.8+ KB

# %%
holidaysinjapan_df = pd.read_csv("../data/holidays_in_japan.csv")
holidaysinjapan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   holiday_date  245 non-null    object
#  1   description   245 non-null    object
# dtypes: object(2)
# memory usage: 4.0+ KB

# %%
train_df = pd.read_csv("../data/train.csv")
venue_info_df = pd.read_csv("../data/venue_information.csv")
match_reports_df = pd.read_csv("../data/match_reports.csv")
holidaysinjapan_df = pd.read_csv("../data/holidays_in_japan.csv")

train_df = train_df.merge(venue_info_df, how="left", on="venue")
train_df = train_df.merge(match_reports_df, how="left", on="id")
train_df = train_df.merge(holidaysinjapan_df, how="left", left_on="match_date", right_on="holiday_date")
# train_df.info()
train_df.isnull().sum()
# Out:
# id                       0
# match_date               0
# kick_off_time            0
# section                  0
# round                    0
# home_team                0
# away_team                0
# venue                    0
# weather                  0
# temperature              0
# humidity                 0
# broadcasters             0
# attendance               0
# capacity                 0
# address                  0
# home_team_player11       0
# home_team_player10       0
# home_team_player9        0
# home_team_player8        0
# home_team_player7        0
# home_team_player6        0
# home_team_player5        0
# home_team_player4        0
# home_team_player3        0
# home_team_player2        0
# home_team_player1        0
# home_team_score          0
# away_team_score          0
# away_team_player1        0
# away_team_player2        0
# away_team_player3        0
# away_team_player4        0
# away_team_player5        0
# away_team_player6        0
# away_team_player7        0
# away_team_player8        0
# away_team_player9        0
# away_team_player10       0
# away_team_player11       0
# holiday_date          3387
# description           3387
# dtype: int64

# %%
display(train_df)
# Out:
#          id  match_date kick_off_time section round home_team away_team  \
# 0      9190  2006-03-04         16:04     第1節   第1日       G大阪        浦和
# 1      9191  2006-03-05         13:00     第1節   第2日        甲府        清水
# 2      9192  2006-03-05         13:35     第1節   第2日      FC東京        大分
# 3      9193  2006-03-05         14:04     第1節   第2日        磐田        福岡
# 4      9194  2006-03-05         14:04     第1節   第2日       名古屋       C大阪
# ...     ...         ...           ...     ...   ...       ...       ...
# 3667  19376  2017-12-02         14:03    第34節   第1日       川崎Ｆ        大宮
# 3668  19377  2017-12-02         14:03    第34節   第1日        甲府        仙台
# 3669  19378  2017-12-02         14:04    第34節   第1日        新潟       Ｃ大阪
# 3670  19379  2017-12-02         14:03    第34節   第1日        磐田        鹿島
# 3671  19380  2017-12-02         14:03    第34節   第1日        神戸        清水
#
#                   venue weather  temperature  ...  away_team_player4  \
# 0               万博記念競技場       晴          8.3  ...         20 堀之内聖 DF
# 1      山梨県小瀬スポーツ公園陸上競技場       晴         12.9  ...          4 高木和道 DF
# 2              味の素スタジアム       晴         12.1  ...         22 上本大海 DF
# 3            静岡スタジアムエコパ       晴         11.6  ...         5 千代反田充 DF
# 4           名古屋市瑞穂陸上競技場       晴         13.1  ...          3 柳本啓成 DF
# ...                 ...     ...          ...  ...                ...
# 3667           等々力陸上競技場       晴         11.7  ...         25 高山和真 DF
# 3668          山梨中銀スタジアム       晴         18.3  ...         27 大岩一貴 DF
# 3669     デンカビッグスワンスタジアム       晴          6.7  ...         15 木本恭生 DF
# 3670       ヤマハスタジアム(磐田)       晴         17.7  ...           3 昌子源 DF
# 3671  神戸総合運動公園ユニバー記念競技場       晴         13.3  ...          45 角田誠 DF
#
#      away_team_player5  away_team_player6   away_team_player7  \
# 0            6 山田暢久 MF         17 長谷部誠 MF          13 鈴木啓太 MF
# 1            3 山西尊裕 DF         13 兵働昭弘 MF           7 伊東輝悦 MF
# 2          5 エジミウソン MF        11 トゥーリオ MF           6 梅田高志 MF
# 3           3 アレックス DF          7 宮崎光平 MF           6 布部陽功 MF
# 4            4 河村崇大 MF         23 下村東美 MF           10 ピンゴ MF
# ...                ...                ...                 ...
# 3667        22 和田拓也 DF           7 江坂任 MF  28 長谷川アーリアジャスール MF
# 3668        50 増嶋竜也 DF          7 奥埜博亮 MF          18 三田啓貴 MF
# 3669     22 マテイヨニッチ DF           6 ソウザ MF          16 水沼宏太 MF
# 3670        16 山本脩斗 DF         20 三竿健斗 MF          4 レオシルバ MF
# 3671         25 松原后 DF         24 増田誓志 MF           20 竹内涼 MF
#
#      away_team_player8 away_team_player9 away_team_player10  \
# 0       8 三都主アレサンドロ MF        18 小野伸二 MF          10 ポンテ FW
# 1           16 枝村匠馬 MF        10 藤本淳吾 MF       18 チョジェジン FW
# 2           17 根本裕一 MF        26 内村圭宏 MF         13 高松大樹 FW
# 3            8 ホベルト MF        14 古賀誠史 MF         27 田中佑昌 FW
# 4           6 ゼカルロス MF         8 森島寛晃 FW         20 西澤明訓 FW
# ...                ...               ...                ...
# 3667        40 茨田陽生 MF        44 瀬川祐輔 MF         16 マテウス FW
# 3668        29 古林将太 MF       16 野津田岳人 MF         30 西村拓真 FW
# 3669        24 山村和也 MF        46 清武弘嗣 MF         8 柿谷曜一朗 FW
# 3670         25 遠藤康 MF       11 レアンドロ MF         33 金崎夢生 FW
# 3671        30 金子翔太 MF   19 ミッチェルデューク MF         23 北川航也 FW
#
#      away_team_player11 holiday_date description
# 0           21 ワシントン FW          NaN         NaN
# 1         17 マルキーニョス FW          NaN         NaN
# 2            9 オズマール FW          NaN         NaN
# 3           36 グラウシオ FW          NaN         NaN
# 4             9 古橋達弥 FW          NaN         NaN
# ...                 ...          ...         ...
# 3667    33 マルセロトスカーノ FW          NaN         NaN
# 3668         11 石原直樹 FW          NaN         NaN
# 3669          9 杉本健勇 FW          NaN         NaN
# 3670          8 土居聖真 FW          NaN         NaN
# 3671           9 鄭大世 FW          NaN         NaN
#
# [3672 rows x 41 columns]
